# %% [markdown]
# <a href="https://colab.research.google.com/github/KayVonte/Snake-Code/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
def calculate_ticket(age, hour):

# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
  if age <= 12:
    base_price = 8.00
  elif age >= 65:
    base_price = 8.00
  else:
    base_price = 12.00

# 3. Logic: If hour < 17, subtract 2 from the price.
  if hour < 17:
    price = base_price - 2.00
  elif hour >= 17:
    price = base_price
  else:
    if hour < 0 or hour > 23:
      print("Please enter a value between 0 and 23.")

# 4. Print the final price.
  print(f"Your ticket price is: ${price:.2f}.")

# PROGRAM LOGIC
# 1. input() for age (int)
age = int(input("Enter customer's age: "))

# 2. input() for movie hour (int)
hour = int(input("Enter the movie's starting hour (0-23): "))

# 3. Call calculate_ticket()
calculate_ticket(age, hour)
# Out:
# Enter customer's age: 25
# Enter the movie's starting hour (0-23): 11
# Your ticket price is: $10.00.
