# %% [markdown]
# <a href="https://colab.research.google.com/github/KayVonte/Snake-Code/blob/main/CourseSetup(%2B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is my second Python comment.
