# %% [markdown]
# <a href="https://colab.research.google.com/github/KayVonte/Snake-Code/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (none)

# FUNCTION DEFINITIONS
# 1. Define palindrome(text)
def is_palindrome(text):
  text = text.lower()

  # 2. Remove the non-alphaneumeric characters and convert to lowercase only.
  reversed_text = text[::-1]

  # 3. Compare the cleaned text when reversed.
  return text == reversed_text

  # 4. Determine whether the text is true or false.
  if palindrome_results:
    print(f' {user_input} ')
    return True

  else:
    print(f' {user_input} ')
    return False

# PROGRAM LOGIC
# 1. Input for palindrome.
user_input = input("Enter a Word: ")
# 2. Call and print the result.
palindrome_results = is_palindrome(user_input)
print(palindrome_results)
print(f'{user_input} is a palindrome. Good Job!')
# Out:
# Enter a Word: Racecar
# True
# Racecar is a palindrome. Good Job!
