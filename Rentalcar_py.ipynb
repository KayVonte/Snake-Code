# %% [markdown]
# <a href="https://colab.research.google.com/github/KayVonte/Snake-Code/blob/main/Rentalcar_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
# IMPORT STATEMENTS
# 1. Import math

# FUNCTION DEFINITIONS
# 1. Define and assign car classification (B, S, L).
# 2. Define mileage: ( 0.35x - 100 ).
# 3. Calcualte total cost: (mileage + classification).

# PROGRAM LOGIC
# 1. Input car classification.
# 2. Input mileage charge.
# 3. Input days rented.
# 4. Print total bill.
