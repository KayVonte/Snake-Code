# %% [markdown]
# <a href="https://colab.research.google.com/github/KayVonte/Snake-Code/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statments

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
name = "KayVonte Plum"
goal = "to learn more about Cybersecurity."
birth_year = 2006
current_year = 2026
# Calculate Age
age = ( current_year - birth_year )
# Print top border
print("=" * 25)
# Print bio sentence
print( "My name is "+ name +" and I am " + str(age) + " years old." " My goal is " + goal +"")
# Print bottom border
print("=" * 25)
# Out:
# ...
# My name is KayVonte Plum and I am 20 years old. My goal is to learn more about Cybersecurity.
# ...
